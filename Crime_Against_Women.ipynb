# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/drive/MyDrive/crimes_against_women_2001-2014.csv",index_col='S.No')

# %%
df
# Out:
#             STATE/UT           DISTRICT  Year  Rape  Kidnapping and Abduction  \
# S.No
# 0     ANDHRA PRADESH           ADILABAD  2001    50                        30
# 1     ANDHRA PRADESH          ANANTAPUR  2001    23                        30
# 2     ANDHRA PRADESH           CHITTOOR  2001    27                        34
# 3     ANDHRA PRADESH           CUDDAPAH  2001    20                        20
# 4     ANDHRA PRADESH      EAST GODAVARI  2001    23                        26
# ...              ...                ...   ...   ...                       ...
# 832      Lakshadweep        Lakshadweep  2014     1                         0
# 833      Lakshadweep  Total District(s)  2014     1                         0
# 834       Puducherry           Karaikal  2014     3                         1
# 835       Puducherry         Puducherry  2014     7                         6
# 836       Puducherry  Total District(s)  2014    10                         7
#
# ...

# %%
df.head()
# Out:
#             STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# S.No
# 0     ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1     ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2     ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3     ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4     ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
#
#       Dowry Deaths  Assault on women with intent to outrage her modesty  \
# S.No
# 0               16                                                149
# 1                7                                                118
# 2               14                                                112
# 3               17                                                126
# 4               12                                                109
#
#       Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# S.No
# ...

# %%
df.tail()
# Out:
#          STATE/UT           DISTRICT  Year  Rape  Kidnapping and Abduction  \
# S.No
# 832   Lakshadweep        Lakshadweep  2014     1                         0
# 833   Lakshadweep  Total District(s)  2014     1                         0
# 834    Puducherry           Karaikal  2014     3                         1
# 835    Puducherry         Puducherry  2014     7                         6
# 836    Puducherry  Total District(s)  2014    10                         7
#
#       Dowry Deaths  Assault on women with intent to outrage her modesty  \
# S.No
# 832              0                                                  1
# 833              0                                                  1
# 834              0                                                 12
# 835              1                                                 20
# 836              1                                                 32
#
#       Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# ...

# %%
df.sample(10)
# Out:
#                STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# S.No
# 622          Tamil Nadu          Karur  2014     1                        15
# 4505       CHHATTISGARH    RAJNANDGAON  2007    54                        11
# 8066      UTTAR PRADESH      BALRAMPUR  2011    10                        50
# 6718              ASSAM          TOTAL  2010  1721                      2767
# 7074            MANIPUR  CHURACHANDPUR  2010     1                         0
# 5592             ODISHA       KEONJHAR  2008    66                        46
# 5143  ARUNACHAL PRADESH          LOHIT  2008     3                         1
# 5918              ASSAM     BONGAIGAON  2009    54                        53
# 4613          JHARKHAND        GIRIDIH  2007    46                        30
# 8193              DELHI     NORTH-EAST  2011    69                       285
#
#       Dowry Deaths  Assault on women with intent to outrage her modesty  \
# S.No
# ...

# %%
df.shape
# Out:
# (10677, 10)

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'Year', 'Rape', 'Kidnapping and Abduction',
#        'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
#        'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
#        'Importation of Girls'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10677 entries, 0 to 836
# Data columns (total 10 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             10677 non-null  object
#  1   DISTRICT                                             10677 non-null  object
#  2   Year                                                 10677 non-null  int64
#  3   Rape                                                 10677 non-null  int64
#  4   Kidnapping and Abduction                             10677 non-null  int64
#  5   Dowry Deaths                                         10677 non-null  int64
#  6   Assault on women with intent to outrage her modesty  10677 non-null  int64
#  7   Insult to modesty of Women                           10677 non-null  int64
# ...

# %%
df.describe()
# Out:
#                Year          Rape  Kidnapping and Abduction  Dowry Deaths  \
# count  10677.000000  10677.000000              10677.000000  10677.000000
# mean    2007.697949     57.989885                 69.888358     20.181699
# std        4.046874    214.230398                311.623450     98.276531
# min     2001.000000      0.000000                  0.000000      0.000000
# 25%     2004.000000      8.000000                  6.000000      1.000000
# 50%     2008.000000     22.000000                 20.000000      5.000000
# 75%     2011.000000     44.000000                 49.000000     16.000000
# max     2014.000000   5076.000000              10626.000000   2469.000000
#
#        Assault on women with intent to outrage her modesty  \
# count                                       10677.000000
# mean                                          113.539196
# std                                           458.903951
# min                                             0.000000
# ...

# %%
df.isna().sum()
# Out:
# STATE/UT                                               0
# DISTRICT                                               0
# Year                                                   0
# Rape                                                   0
# Kidnapping and Abduction                               0
# Dowry Deaths                                           0
# Assault on women with intent to outrage her modesty    0
# Insult to modesty of Women                             0
# Cruelty by Husband or his Relatives                    0
# Importation of Girls                                   0
# dtype: int64

# %%
df['DISTRICT'].nunique()
# Out:
# 1605

# %%
df['DISTRICT'].value_counts()
# Out:
# TOTAL         408
# G.R.P.         49
# SOUTH          41
# NORTH          41
# WEST           39
#              ...
# Shopian         1
# Sopore          1
# Srinagar        1
# Udhampur        1
# Puducherry      1
# Name: DISTRICT, Length: 1605, dtype: int64

# %% [markdown]
# In some cases, districts are further subdivided into sub-divisions, and in others directly into tehsils or talukas. As of 20 November 2023, there are a total of 806 districts, up from the 640 in the 2011 Census of India and the 593 recorded in the 2001 Census of India,and here this field shows 1605. This means there is too much falsy data here and it is also tough to clean this field.

# %%
df['STATE/UT'].nunique()
# Out:
# 72

# %%
df['STATE/UT'].value_counts()
# Out:
# UTTAR PRADESH     878
# MADHYA PRADESH    628
# MAHARASHTRA       552
# BIHAR             540
# TAMIL NADU        469
#                  ...
# A&N Islands         4
# Chandigarh          4
# D&N Haveli          4
# Lakshadweep         4
# A & N Islands       4
# Name: STATE/UT, Length: 72, dtype: int64

# %%
df['STATE/UT'].unique()
# Out:
# array(['ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR',
#        'CHHATTISGARH', 'GOA', 'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH',
#        'JAMMU & KASHMIR', 'JHARKHAND', 'KARNATAKA', 'KERALA',
#        'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA', 'MIZORAM',
#        'NAGALAND', 'ODISHA', 'PUNJAB', 'RAJASTHAN', 'SIKKIM',
#        'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH', 'UTTARAKHAND',
#        'WEST BENGAL', 'A & N ISLANDS', 'CHANDIGARH', 'D & N HAVELI',
#        'DAMAN & DIU', 'DELHI', 'LAKSHADWEEP', 'PUDUCHERRY',
#        'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
# ...

# %% [markdown]
# There is total 28 states and 8 Union territories (Total->36) in india as per August 2023 and here this field shows 72. But let's clean this field as this field is more useful in our analysis

# %%
def remove_uppercase(row):
  state=row['STATE/UT'].strip()
  state=state.upper()
  return state

# %%
state_series=df.apply(remove_uppercase,axis=1)
df['STATE/UT']=state_series

# %%
df['STATE/UT']
# Out:
# S.No
# 0      ANDHRA PRADESH
# 1      ANDHRA PRADESH
# 2      ANDHRA PRADESH
# 3      ANDHRA PRADESH
# 4      ANDHRA PRADESH
#             ...
# 832       LAKSHADWEEP
# 833       LAKSHADWEEP
# 834        PUDUCHERRY
# 835        PUDUCHERRY
# 836        PUDUCHERRY
# Name: STATE/UT, Length: 10677, dtype: object

# %%
df['STATE/UT'].unique()
# Out:
# array(['ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR',
#        'CHHATTISGARH', 'GOA', 'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH',
#        'JAMMU & KASHMIR', 'JHARKHAND', 'KARNATAKA', 'KERALA',
#        'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA', 'MIZORAM',
#        'NAGALAND', 'ODISHA', 'PUNJAB', 'RAJASTHAN', 'SIKKIM',
#        'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH', 'UTTARAKHAND',
#        'WEST BENGAL', 'A & N ISLANDS', 'CHANDIGARH', 'D & N HAVELI',
#        'DAMAN & DIU', 'DELHI', 'LAKSHADWEEP', 'PUDUCHERRY', 'A&N ISLANDS',
#        'D&N HAVELI', 'DELHI UT', 'TELANGANA'], dtype=object)

# %%
df['STATE/UT'].replace("DELHI UT",'DELHI',inplace=True)
df['STATE/UT'].replace("D&N HAVELI",'D & N HAVELI',inplace=True)
df['STATE/UT'].replace("A&N ISLANDS",'A & N ISLANDS',inplace=True)

# %%
df['STATE/UT'].nunique()
# Out:
# 36

# %% [markdown]
# Now this field has correct Data

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'Year', 'Rape', 'Kidnapping and Abduction',
#        'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
#        'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
#        'Importation of Girls'],
#       dtype='object')

# %%
df.rename(columns={'Dowry Deaths':'Dowry_Deaths','Kidnapping and Abduction':'Kidnapping_Abduction','Assault on women with intent to outrage her modesty':
'Assault_on_women','Cruelty by Husband or his Relatives':'Domestic_cruelity','Insult to modesty of Women':'Insult_Women_modesty','Importation of Girls':'Importation_Girls'},inplace=True)

# %%
df.rename(columns={'Insult to modesty of Women':'Insult_Women_modesty'})
# Out:
#             STATE/UT           DISTRICT  Year  Rape  Kidnapping_Abduction  \
# S.No
# 0     ANDHRA PRADESH           ADILABAD  2001    50                    30
# 1     ANDHRA PRADESH          ANANTAPUR  2001    23                    30
# 2     ANDHRA PRADESH           CHITTOOR  2001    27                    34
# 3     ANDHRA PRADESH           CUDDAPAH  2001    20                    20
# 4     ANDHRA PRADESH      EAST GODAVARI  2001    23                    26
# ...              ...                ...   ...   ...                   ...
# 832      LAKSHADWEEP        Lakshadweep  2014     1                     0
# 833      LAKSHADWEEP  Total District(s)  2014     1                     0
# 834       PUDUCHERRY           Karaikal  2014     3                     1
# 835       PUDUCHERRY         Puducherry  2014     7                     6
# 836       PUDUCHERRY  Total District(s)  2014    10                     7
#
# ...

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'Year', 'Rape', 'Kidnapping_Abduction',
#        'Dowry_Deaths', 'Assault_on_women', 'Insult_Women_modesty',
#        'Domestic_cruelity', 'Importation_Girls'],
#       dtype='object')

# %% [markdown]
# Data Cleaning is done,
# lets Start Analysis

# %%
crime=list(df.columns[3:])
crime
# Out:
# ['Rape',
#  'Kidnapping_Abduction',
#  'Dowry_Deaths',
#  'Assault_on_women',
#  'Insult_Women_modesty',
#  'Domestic_cruelity',
#  'Importation_Girls']

# %%
victims=df[crime].sum()
victims
# Out:
# Rape                     619158
# Kidnapping_Abduction     746198
# Dowry_Deaths             215480
# Assault_on_women        1212258
# Insult_Women_modesty     292756
# Domestic_cruelity       2233888
# Importation_Girls          1872
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# %%
len(crime)
# Out:
# 7

# %%
# %matplotlib inline
plt.style.use('dark_background')

# %%
plt.pie(victims,radius=1,labels=crime,autopct='%1.2f%%',shadow=True,explode=[0.2,0,0,0,0,0.1,0.1],colors=['blue','orange','purple','green','pink','red','brown'])
plt.title('Women  victime of various crimes',bbox={'facecolor':'black'},color='red',pad=15)
plt.show()

# %%
victims.sum()
# Out:
# 5321610

# %% [markdown]
# More than 5 million number of females, over the years 2001-2014, have been a victim of assault, violance, rape or even death, in India alone.

# %% [markdown]
# #Crimes across the years

# %%
df
# Out:
#             STATE/UT           DISTRICT  Year  Rape  Kidnapping_Abduction  \
# S.No
# 0     ANDHRA PRADESH           ADILABAD  2001    50                    30
# 1     ANDHRA PRADESH          ANANTAPUR  2001    23                    30
# 2     ANDHRA PRADESH           CHITTOOR  2001    27                    34
# 3     ANDHRA PRADESH           CUDDAPAH  2001    20                    20
# 4     ANDHRA PRADESH      EAST GODAVARI  2001    23                    26
# ...              ...                ...   ...   ...                   ...
# 832      LAKSHADWEEP        Lakshadweep  2014     1                     0
# 833      LAKSHADWEEP  Total District(s)  2014     1                     0
# 834       PUDUCHERRY           Karaikal  2014     3                     1
# 835       PUDUCHERRY         Puducherry  2014     7                     6
# 836       PUDUCHERRY  Total District(s)  2014    10                     7
#
# ...

# %%
df1=df.groupby('Year')[crime].sum()
sum_df=df1.reset_index()
sum_df
# Out:
#     Year   Rape  Kidnapping_Abduction  Dowry_Deaths  Assault_on_women  \
# 0   2001  32150                 29290         13702             68248
# 1   2002  32746                 29012         13644             67886
# 2   2003  31694                 26592         12416             65878
# 3   2004  36466                 31156         14052             69134
# 4   2005  36718                 31500         13574             68350
# 5   2006  38696                 34828         15236             73234
# 6   2007  41474                 40832         16186             77468
# 7   2008  42934                 45878         16344             80826
# 8   2009  42794                 51482         16766             77422
# 9   2010  44344                 59590         16782             81226
# 10  2011  48412                 71130         17236             85936
# 11  2012  49846                 76524         16466             90702
# ...

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'Year', 'Rape', 'Kidnapping_Abduction',
#        'Dowry_Deaths', 'Assault_on_women', 'Insult_Women_modesty',
#        'Domestic_cruelity', 'Importation_Girls'],
#       dtype='object')

# %%
# %matplotlib inline
plt.style.use('dark_background')

# %%
def millions(x,pos):
  return "%1.1fm" %(x*1e-5)

# %%
order = ['Importation_Girls', 'Dowry_Deaths', 'Insult_Women_modesty', 'Kidnapping_Abduction', 'Rape', 'Assault_on_women', 'Domestic_cruelity']

fig, ax = plt.subplots(figsize=(40, 20))
sum_df.plot(x='Year', y=order, ax=ax, rot=45, kind='bar',width=0.50,  colormap='inferno')

plt.title("Different crime-cases committed in India(2001-2014)", fontsize=50, bbox={'facecolor': 'black', 'pad': 3}, color='red',pad=30)
plt.xlabel("Year", fontsize=30)
plt.ylabel("Cases (Millions)", fontsize=30)
plt.tick_params(labelsize=30)



ax.yaxis.set_major_formatter(ticker.FuncFormatter(millions))

plt.minorticks_on()
plt.grid(which='major', color='g', linestyle=':', linewidth='1')
plt.grid(which='minor', color='red', linestyle=':', linewidth='0.5')

plt.legend(fontsize=20)
plt.tight_layout()
plt.show()

# %%
ax=df1.plot(figsize=(12,6),marker='*', colormap='rainbow',)
plt.xlabel('Year',fontsize=12)
plt.ylabel('Cases',fontsize=12)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(millions))
plt.show()

# %% [markdown]
# We come to know that domestic cruelty is the biggest threat to women's safety in India,and it is increasing rapidly. Secondly, importation of girls is negligible as compared to other crimes.

# %%
crimes = ['Rape', 'Kidnapping_Abduction', 'Dowry_Deaths', 'Assault_on_women', 'Insult_Women_modesty', 'Domestic_cruelity']
colors = ['navy', 'deeppink', 'red', 'deepskyblue', 'green', 'orange']
titles = ['Rape cases', 'Kidnapping and Abduction cases', 'Dowry deaths', 'Assault to women modesty', 'Insult of women modesty', 'Domestic Violence cases']

fig, axes = plt.subplots(2, 3, figsize=(25, 15))
axes = axes.flatten()

for i, crime in enumerate(crimes):
    ax = axes[i]
    ax.set_xlabel('Year', fontsize=15)
    ax.set_ylabel('Cases', fontsize=15)
    ax.set_title(titles[i], fontsize=20)
    ax.bar(df.Year, df[crime], color=colors[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# The cases have increased over the years
# 2014 was the year, when violance against women was reported the maximum

# %%
plt.bar(df.Year, df.Importation_Girls, color = 'purple')
plt.title("Importation of Girls",bbox={'facecolor':'black','pad':5},pad=14)
plt.xlabel('Year')
plt.ylabel('Cases')
plt.show()

# %%
plt.bar(df.Year,df.Importation_Girls,color='red')
plt.title("Importation of Girls",bbox={'facecolor':'black'},pad=14)
plt.xlabel('Year')
plt.ylabel('cases')
plt.show()

# %% [markdown]
# ##Frequency of cases reported

# %%
count_df=df.groupby('Year')[['STATE/UT']].count()
count_df.head()
# Out:
#       STATE/UT
# Year
# 2001       716
# 2002       719
# 2003       728
# 2004       729
# 2005       733

# %%
plt.figure(figsize=(10,5))
plt.ylabel('Year',fontsize=15)
plt.title("How frequently cases have been reported from every state Year wise",bbox={'facecolor':"black",'pad':5},color='red',pad=20)
sns.heatmap(count_df,cmap='inferno')
# Out:
# <Axes: title={'center': 'How frequently cases have been reported from every state Year wise'}, ylabel='Year'>

# %% [markdown]
# This heatmap shows how states' names started appearing more frequently on the dataset, for reporting crimes and sadly the crime only increased with the passing year.
#
# It gives us the conclusion that overall(cases under each category), from every state, has increased with time, not decreased.

# %%
state_df=df.groupby('STATE/UT')[crimes].sum().sum(axis=1).sort_values()
df2=state_df.to_frame().rename(columns={0:'crimes_in_state'})
df2.reset_index(inplace=True)
df2.tail()
# Out:
#           STATE/UT  crimes_in_state
# 31  MADHYA PRADESH           466952
# 32       RAJASTHAN           470172
# 33     WEST BENGAL           537722
# 34  ANDHRA PRADESH           575320
# 35   UTTAR PRADESH           582392

# %%
li=[df2.crimes_in_state.sum()]*5
df3=df2.tail()
df3.insert(2,'crimes_in_India',li)
ax=df3.plot(x='STATE/UT',kind='barh',stacked=True,colormap='rainbow')
ax.xaxis.set_major_formatter(ticker.FuncFormatter(millions))
plt.legend(bbox_to_anchor=(1.05,1.0))
plt.show()

# %% [markdown]
# UTTAR PRADESH has the highest crime reported in this period of time

# %% [markdown]
# #Cases of domestic violence and women assault

# %%
dc = df['Domestic_cruelity'].sum()
wa = df['Assault_on_women'].sum()
tc = df[crimes].sum().sum()

fig, ax = plt.subplots(figsize=(6, 6))

plt.title("Cases of Domestic Violence and Women Assault", bbox={'facecolor': 'black', 'pad': 5}, color='red' ,pad=25)
bar_width = 0.4

ax.bar(['Domestic_Cruelty', 'Assault_on_women'], [tc, tc], color='red', width=bar_width, label='Total crime cases in India')
ax.bar(['Domestic_Cruelty', 'Assault_on_women'], [dc, wa], color='grey', width=bar_width, label='Cases of domestic violence and women assault')

ax.yaxis.set_major_formatter(ticker.FuncFormatter(millions))

ax.legend(fontsize=10, bbox_to_anchor=(1.05, 1), loc='upper left' ,borderaxespad=0.)
plt.xlabel('Crime Type', fontsize=12,color='red')
plt.ylabel('Cases (Millions)', fontsize=12,color='red')
plt.show()

# %% [markdown]
# Insights
#
# * More than 5 million females has been a victim of some or other type of Violance, based on their gender,starting from rape to importing them for buisness.
# *  We summarised the TOTAL number of cases happening, in 2001-2014, by each state and also found out the top 5 states where maximum number of TOTAL cases has been reported from 2001-2014,state wise.
# * We concluded from the series of bar graphs that 2014 was the year, when crimes were reported the highest under each category.
# * We also merged the data in two different cases, first one being "Maximum number of rape cases" and "Maximum number of Importation cases", where we found out it is Madhya Pradesh and in second one being "Maximum number of rape cases" and "Maximum number of Deaths due to Dowry cases", which we concluded to be Uttar Pradesh.
# * We concluded that crimes against women has been on increase.

# %%
df.to_excel(r'C://Users//Lenovo//Desktop//python//Crime against women.xlsx',encoding='latin_1')
